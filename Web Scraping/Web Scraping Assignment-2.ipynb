# %% [markdown]
# # Web Scraping Assignment-2****

# %%
# Let's install Selenium First:

# !pip install selenium

# %%
# Let's import necessary libraries:

import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException ,NoSuchElementException
from selenium.webdriver.common.by import By

import pandas as pd

import warnings
warnings.filterwarnings('ignore')
import time

# %%
# Let's connect to the Web Driver:

driver = webdriver.Chrome(r"C:\Users\hp\Downloads\chromedriver_win32\chromedriver.exe") # pass the path where we have saved chromedriver.

# %% [markdown]
# # 1. Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You  have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data from:
#
# https://www.naukri.com/

# %%
# Opening the Naukri page on automated chrome browser:

driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Analyst")

# %%
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
exp_req=[]

# %%
# To scrap required details:

title = driver.find_elements(By.XPATH,'//a[@class ="title ellipsis"]')
job_title=[]
for i in title[0:10]:
    title_1=i.text
    job_title.append(title_1)

# %%
# Scraping job location from given page:

location = driver.find_elements(By.XPATH,'//span[@class = "ellipsis fleft locWdth"]')
job_location=[]
for i in location[0:10]:
    location_1 = i.text
    job_location.append(location_1) # To scrap required details:

# %%
# Scraping Company name from given page:

company = driver.find_elements(By.XPATH ,'//a[@class="subTitle ellipsis fleft"]')
company_name=[]
for i in company[0:10]:
    company_1= i.text
    company_name.append(company_1)

# %%
# Scraping Experience Required from given page:

exp = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
exp_req=[]
for i in exp[0:10]:
    exp_1 = i.text
    exp_req.append(exp_1)

# %%
len(job_title_1)
# Out:
# 10

# %%
print(len(job_title_1),len(job_location_1),len(company_name_1),len(exp_req_1))
# Out:
# 10 10 10 10

# %% [markdown]
# # Output:

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title_1,'Location':job_location_1,'Company_Name':company_name_1,'Experience':exp_req_1})
df
# Out:
#                                                Title  \
# 0         Data Analyst/Senior Analyst - R/SQL/Python
# 1   Junior Data Analyst/ Scientist- Fresher Position
# 2                                       Data Analyst
# 3  data analyst / data analytics - US MNC (analyt...
# 4                               Data Analyst (Jr/Sr)
# 5      Business Data Analyst (Sr Exe / Asst Manager)
# 6            Data Analysts - Compliance Surveillance
# 7                                    Sr Data Analyst
# 8  Job Opportunity with Leading MNC - Senior Data...
# 9              Manager/Senior Manager - Data Analyst
#
#                                             Location  \
# 0  Temp. WFH - Bangalore/Bengaluru, Kolkata, Mumb...
# 1  Hybrid - Bangalore/Bengaluru, New Delhi, Mumba...
# 2                                Bangalore/Bengaluru
# 3  Temp. WFH - Bangalore/Bengaluru, Gurgaon/Gurugram
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # 2. Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data from:
#
# https://www.naukri.com/

# %%
driver.get("https://www.naukri.com/")

# %%
designation_2 = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation_2.send_keys("Data Scientist")

# %%
location_2 = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location_2.send_keys("Bangalore")

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title__=[]
job_location__=[]
company_name__=[]

# %%
# To scrap required details:

title__ = driver.find_elements(By.XPATH,'//a[@class ="title ellipsis"]')
job_title__=[]
for i in title__[0:10]:
    title_1=i.text
    job_title__.append(title_1)

# %%
len(job_title__)
# Out:
# 10

# %%
location__ = driver.find_elements(By.XPATH,'//span[@class = "ellipsis fleft locWdth"]')
job_location__=[]
for i in location__[0:10]:
    location_1_ = i.text
    job_location__.append(location_1_)# To scrap required details:

# %%
company__ = driver.find_elements(By.XPATH ,'//a[@class="subTitle ellipsis fleft"]')
company_name__=[]
for i in company__[0:10]:
    company_1= i.text
    company_name__.append(company_1)

# %%
print(len(job_title__),len(job_location__),len(company_name__))
# Out:
# 10 10 10

# %% [markdown]
# # Output:

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title__,'Location':job_location__,'Company_Name':company_name__})
df
# Out:
#                               Title  \
# 0                    Data Scientist
# 1                    Data Scientist
# 2           Data Science Specialist
# 3  Analystics & Modeling Specialist
# 4                     Data Engineer
# 5                    Data Scientist
# 6               Lead Data Scientist
# 7                    Data Scientist
# 8    Data Scientist Knowledge graph
# 9                    Data Scientist
#
#                                             Location           Company_Name
# 0  Noida, Kolkata, Mumbai, Hyderabad/Secunderabad...              Capgemini
# 1  Temp. WFH - Hyderabad/Secunderabad, Pune, Chen...          Tech Mahindra
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...              Accenture
# 3  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...              Accenture
# 4      Temp. WFH - Pune, Chennai, Mumbai (All Areas)  Hexaware Technologies
# 5                                Bangalore/Bengaluru                    ANZ
# ...

# %% [markdown]
# # 3. You have to use the location and salary filter. You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs From :
#
# https://www.naukri.com/

# %%
driver.get("https://www.naukri.com/")

# %%
designation_3 = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation_3.send_keys("Data Scientist")

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
location_1_ = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]').click()

# %%
salary_1_ = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]').click()

# %%
job_title_3=[]
job_location_3=[]
company_name_3=[]
exp_req_3=[]

# %%
title = driver.find_elements(By.XPATH,'//a[@class ="title ellipsis"]')
job_title_3=[]
for i in title[0:10]:
    title_1=i.text
    job_title_3.append(title_1)

# %%
len(job_title_3)
# Out:
# 10

# %%
location = driver.find_elements(By.XPATH,'//span[@class = "ellipsis fleft locWdth"]')
job_location_3=[]
for i in location[0:10]:
    location_1 = i.text
    job_location_3.append(location_1)

# %%
company = driver.find_elements(By.XPATH ,'//a[@class="subTitle ellipsis fleft"]')
company_name_3=[]
for i in company[0:10]:
    company_1= i.text
    company_name_3.append(company_1)

# %%
exp = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
exp_req_3=[]
for i in exp[0:10]:
    exp_1 = i.text
    exp_req_3.append(exp_1)

# %%
print(len(job_title_3),len(job_location_3),len(company_name_3),len(exp_req_3))
# Out:
# 10 10 10 10

# %% [markdown]
# # Output:

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title_3,'Location':job_location_3,'Company_Name':company_name_3,'Experience':exp_req_3})
df
# Out:
#                                         Title  \
# 0                        Analyst-Data Science
# 1                              Data Scientist
# 2                              Data Scientist
# 3  AWS Data Warehouse Developer - IT Industry
# 4                              Data Scientist
# 5                              Data Scientist
# 6                              Data Scientist
# 7                       Junior Data Scientist
# 8                                     Modeler
# 9                    Associate Data Scientist
#
#                                             Location  \
# 0                                   Gurgaon/Gurugram
# 1                                              Noida
# 2  Delhi / NCR, Noida(Sector-136 Noida), Ghaziaba...
# 3      Delhi / NCR, Bangalore/Bengaluru, Maharashtra
# 4                                   Permanent Remote
# 5                                              Noida
# 6  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# ...

# %% [markdown]
# # 4. Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#        1. Brand
#        2. ProductDescription
#        3. Price
#
# From:  http://www.flipkart.com/

# %%
driver.get("http://www.flipkart.com/")

# %%
product = driver.find_element(By.CLASS_NAME,'_3704LK')
product.send_keys('sunglasses')

# %%
search_ = driver.find_element(By.CLASS_NAME,"_34RNph")
search_.click()

# %%
brand_1=[]
product_disc_1=[]
price_1=[]

# %%
brand_name = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_name[0:35]:
    brand_=i.text
    brand_1.append(brand_)

# %%
len(brand_1)
# Out:
# 35

# %%
pr_dis = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in pr_dis[0:35]:
    pro_=i.text
    product_disc_1.append(pro_)

# %%
price = driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price[0:35]:
    price_=i.text
    price_1.append(price_)

# %%
print(len(brand_1),len(product_disc_1),len(price_1))
# Out:
# 35 35 35

# %%
df_1 = pd.DataFrame({'Brand':brand_1,'Product_Discription':product_disc_1,'Price':price_1})
df_1
# Out:
#                 Brand                                Product_Discription  \
# 0         like future   UV Protection Rectangular Sunglasses (Free Size)
# 1              Resist  Toughened Glass Lens, UV Protection, Riding Gl...
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 4            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 5           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 6          PHENOMENAL         UV Protection Retro Square Sunglasses (53)
# 7             Cluemen       Gradient Retro Square Sunglasses (Free Size)
# 8           Elligator                UV Protection Round Sunglasses (54)
# 9                SRPM             UV Protection Wayfarer Sunglasses (50)
# 10         LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...
# 11       Singco India  Gradient, Toughened Glass Lens, UV Protection ...
# ...

# %%
page_2 = driver.find_element(By.XPATH,'//a[@class="ge-49M"]').click()

# %%
brand_2=[]
product_disc_2=[]
price_2=[]

# %%
brand_name_ = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_name_[0:35]:
    brand__=i.text
    brand_2.append(brand__)

# %%
pr_dis_ = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in pr_dis_[0:35]:
    pro__=i.text
    product_disc_2.append(pro__)

# %%
price_ = driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_[0:35]:
    price__=i.text
    price_2.append(price__)

# %%
print(len(brand_2),len(product_disc_2),len(price_2))
# Out:
# 35 35 35

# %%
df_2 = pd.DataFrame({'Brand':brand_2,'Product_Discription':product_disc_2,'Price':price_2})
df_2
# Out:
#              Brand                                Product_Discription  \
# 0        Rich Club         UV Protection Retro Square Sunglasses (54)
# 1         Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 2        Elligator                UV Protection Round Sunglasses (53)
# 3   ROZZETTA CRAFT              UV Protection Aviator Sunglasses (55)
# 4        New Specs  UV Protection Retro Square Sunglasses (Free Size)
# 5         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 6           PIRASO              Polarized Wrap-around Sunglasses (45)
# 7      Eyewearlabs     Polarized, UV Protection Round Sunglasses (51)
# 8           PIRASO          UV Protection Rectangular Sunglasses (52)
# 9            NuVew  UV Protection, Mirrored Wayfarer, Rectangular ...
# 10       Elligator  Others Cat-eye, Retro Square, Wayfarer Sunglas...
# 11        TheWhoop  UV Protection, Gradient Over-sized Sunglasses ...
# ...

# %%
page_3 = driver.find_element(By.XPATH,'//a[@class="ge-49M"]').click()

# %%
brand_3=[]
product_disc_3=[]
price_3=[]

# %%
brand_name__ = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_name__[0:30]:
    brand___=i.text
    brand_3.append(brand___)

# %%
pr_dis__ = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in pr_dis__[0:30]:
    pro___=i.text
    product_disc_3.append(pro___)

# %%
price__ = driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price__[0:30]:
    price___=i.text
    price_3.append(price___)

# %%
print(len(brand_3),len(product_disc_3),len(price_3))
# Out:
# 30 30 30

# %%
df_3 = pd.DataFrame({'Brand':brand_3,'Product_Discription':product_disc_3,'Price':price_3})
df_3
# Out:
#                 Brand                                Product_Discription  \
# 0      RESIST EYEWEAR  Polarized, Riding Glasses, UV Protection Wayfa...
# 1      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 4            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 5           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 6          PHENOMENAL         UV Protection Retro Square Sunglasses (53)
# 7         like future   UV Protection Rectangular Sunglasses (Free Size)
# 8           Elligator                UV Protection Round Sunglasses (54)
# 9                SRPM             UV Protection Wayfarer Sunglasses (50)
# 10      VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)
# 11            Cluemen       Gradient Retro Square Sunglasses (Free Size)
# ...

# %% [markdown]
# **Here we have to work on 3 different pages , and on one page there are only 40 products. But all arrays must be of same length , so i have to select 35,35 and 30 , to scrap 100 sunglasses.**

# %% [markdown]
# # Output:

# %%
# Let's concatenate:

Output = pd.concat([df_1,df_2,df_3] ,ignore_index=True)
Output[:100]
# Out:
#            Brand                                Product_Discription  \
# 0    like future   UV Protection Rectangular Sunglasses (Free Size)
# 1         Resist  Toughened Glass Lens, UV Protection, Riding Gl...
# 2       Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3      Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 4       Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# ..           ...                                                ...
# 95        PIRASO  Gradient, UV Protection Wayfarer Sunglasses (F...
# 96      Fastrack              UV Protection Aviator Sunglasses (88)
# 97  Silver Kartz      Others Wayfarer, Retro Square Sunglasses (50)
# 98          SRPM       UV Protection Aviator Sunglasses (Free Size)
# 99      Fastrack  Riding Glasses, UV Protection, Night Vision Sp...
#
#                                  Price
# 0       ₹179₹99982% off\nFree delivery
# 1   ₹1,399₹4,99972% off\nFree delivery
# ...

# %% [markdown]
# **Note:  Here is the Final output.**

# %% [markdown]
# # 5. Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
#
# https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART
#
#                To find:
#                 Rating
#                 Review summary
#                 Full review

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART')

# %%
Rating=[]
Review_summary=[]
Full_review=[]

# %%
start=0
end=10
for page in range(start,end):
    rating__=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating__:
        Rating.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
len(Rating)
# Out:
# 100

# %%
Review_Summary=[]

# %%
start_=0
end_=10
for page in range(start_,end_):
    review_summ_=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in review_summ_:
        Review_Summary.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
len(Review_Summary)
# Out:
# 100

# %%
Full_Review=[]

# %%
start__=0
end__=10
for page in range(start__,end__):
    full_rev_=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full_rev_:
        Full_Review.append(i.text)
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
len(Full_Review)
# Out:
# 100

# %% [markdown]
# # Output:

# %%
df=pd.DataFrame({'Rating':Rating,'Review_Summary':Review_Summary,'Full_Review':Full_Review})
df
# Out:
#    Rating       Review_Summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      5          Good choice
# 96      5     Perfect product!
# 97      5     Perfect product!
# 98      5   Highly recommended
# 99      4   Highly recommended
#
#                                           Full_Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  Value for money\n5 star rating\nExcellent came...
# 97  What a camera .....just awesome ..you can feel...
# ...

# %% [markdown]
# # 6. Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field. You have to scrape 3 attributes of each sneaker:
#            1. Brand
#            2. ProductDescription
#            3. Price
#
# From : https://www.flipkart.com/

# %%
driver.get('https://www.flipkart.com/')

# %%
sneaker = driver.find_element(By.CLASS_NAME,'_3704LK')
sneaker.send_keys('sneakers')

# %%
search= driver.find_element(By.CLASS_NAME,'_34RNph')
search.click()

# %%
brand=driver.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand:
    brand_name.append(i.text)
    
product=driver.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product:
    product_desc.append(i.text)
    
price=driver.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price:
    product_price.append(i.text)

# %%
print(len(product_desc),len(product_price),len(brand_name))
# Out:
# 38 40 40

# %%
sneaker1=pd.DataFrame({'Brand Name':brand_name[:30],'Product Description':product_desc[:30], 'Product Price':product_price[:30]})
sneaker1
# Out:
#                Brand Name                                Product Description  \
# 0                 Numenzo                                   Sneakers For Men
# 1                     GVR                CLASSIC CT SNEAKER Sneakers For Men
# 2     World Wear Footwear  5011-Latest Collection Stylish & Trendy Casual...
# 3                    aadi  Synthetic Leather |Lightweight|Comfort|Summer|...
# 4                  ADIDAS                     STREET ICON M Sneakers For Men
# 5             Asian Shoes  Future-04 casual shoes for men | Latest Stylis...
# 6                    aadi  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...
# 7                     SFR  2006 Trenddy Fashion Sporty Casuals Sneakers R...
# 8                    PUMA                    ST Activate V2 Sneakers For Men
# 9                     SFR                                   Sneakers For Men
# 10                   PUMA                           Neptune Sneakers For Men
# ...

# %%
page_2=driver.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand__=driver.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand__:
    brand_name.append(i.text)
    
product_=driver.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product_:
    product_desc.append(i.text)
    
price_=driver.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price_:
    product_price.append(i.text)
    
    
sneaker2=pd.DataFrame({'Brand Name':brand_name[:30],'Product Description':product_desc[:30], 'Product Price':product_price[:30]})
sneaker2
# Out:
#              Brand Name                                Product Description  \
# 0           Asian Shoes  Future-04 casual shoes for men | Latest Stylis...
# 1                 Sparx                            SM-671 Sneakers For Men
# 2                DUCATI                      DT-SS22-128B Sneakers For Men
# 3               Numenzo                                   Sneakers For Men
# 4                 asics                           fuzor B Sneakers For Men
# 5                Shozie  Stylish Sneakers Shoes for Women And Girls Sne...
# 6       U.S. POLO ASSN.                          FITZ 2.0 Sneakers For Men
# 7              RapidBox                                   Sneakers For Men
# 8                Shozie  Stylish Walking Partywear Sneakers Casual Shoe...
# 9                 asics                           fuzor B Sneakers For Men
# 10                 PUMA                           Skipper Sneakers For Men
# ...

# %%
page_3=driver.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand___=driver.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand___:
    brand_name.append(i.text)
    
product___=driver.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product___:
    product_desc.append(i.text)
    
price___=driver.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price___:
    product_price.append(i.text)
    
sneaker3=pd.DataFrame({'Brand Name':brand_name[:30],'Product Description':product_desc[:30], 'Product Price':product_price[:30]})

# %%
page_4=driver.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand____=driver.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand____:
    brand_name.append(i.text)
    
product____=driver.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product____:
    product_desc.append(i.text)
    
price____=driver.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price____:
    product_price.append(i.text)
    
    
sneaker4=pd.DataFrame({'Brand Name':brand_name[:10],'Product Description':product_desc[:10], 'Product Price':product_price[:10]})

# %% [markdown]
# # Output

# %%
sneaker=pd.concat([sneaker1,sneaker2,sneaker3,sneaker4], ignore_index=True)
sneaker[:100]
# Out:
#              Brand Name                                Product Description  \
# 0               Numenzo                                   Sneakers For Men
# 1                   GVR                CLASSIC CT SNEAKER Sneakers For Men
# 2   World Wear Footwear  5011-Latest Collection Stylish & Trendy Casual...
# 3                  aadi  Synthetic Leather |Lightweight|Comfort|Summer|...
# 4                ADIDAS                     STREET ICON M Sneakers For Men
# ..                  ...                                                ...
# 95               Shozie  Stylish Sneakers Shoes for Women And Girls Sne...
# 96      U.S. POLO ASSN.                          FITZ 2.0 Sneakers For Men
# 97              Numenzo                                   Sneakers For Men
# 98               Shozie  Stylish Walking Partywear Sneakers Casual Shoe...
# 99                asics                           fuzor B Sneakers For Men
#
#    Product Price
# 0           ₹599
# 1           ₹749
# ...

# %% [markdown]
# # 7. Go to webpage Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” From:
#
# https://www.amazon.in/
#
# **After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:**
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver.get('https://www.amazon.in/')

# %%
purchase=driver.find_element(By.ID,"twotabsearchtextbox")
purchase.send_keys("Laptop")

# %%
search = driver.find_element(By.ID,'nav-search-submit-button')
search.click()

# %%
filterr= driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[2]/li[12]/span/a/span').click()

# %%
Title=[]

# %%
title=driver.find_elements("xpath",'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
Title=[]
for i in title[0:10]:
    Title.append(i.text)

# %%
len(Title)
# Out:
# 10

# %%
Ratings=[]

# %%
ratings=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')
Ratings=[]
for i in ratings[0:10]:
    Ratings.append(i.text)

# %%
len(Ratings)
# Out:
# 10

# %%
Price=[]

# %%
price= driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
Price=[]
for i in price[0:10]:
    Price.append(i.text)

# %%
len(Price)
# Out:
# 10

# %% [markdown]
# # Output:

# %%
df= pd.DataFrame({'Title':Title,'Ratings':Ratings,'Price':Price})
df
# Out:
#                                                Title     Ratings     Price
# 0  Fujitsu UH-X 11th Gen Intel Core i7 13.3" FHD ...   4.3\n(91)    94,990
# 1  LG Gram14 Intel EVO-[12th Gen Corei7/Win11/16G...   4.0\n(43)    84,500
# 2  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...    2.8\n(8)    56,990
# 3  Acer Nitro 5 Gaming Laptop Intel core i7 11th ...    4.5\n(9)    78,106
# 4  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...   4.2\n(67)    79,990
# 5  HP Victus Gaming Latest 12th Gen Intel Core i7...  4.3\n(106)    84,990
# 6  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...  3.9\n(104)    94,630
# 7  Dell Inspiron 5320 Laptop, i7-1260P, 16GB LPDD...    4.0\n(5)    89,999
# 8  ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FH...   4.6\n(49)    96,400
# 9  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...   3.5\n(11)  1,02,490

# %% [markdown]
# # 8. : Write a python program to scrape data for Top 1000 Quotes of All Time. From:
#
# http://www.azquotes.com/
#
# To find:
#
# a) Quote
# b) Author
# c) Type Of Quotes

# %%
driver.get('http://www.azquotes.com/')

# %%
top= driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a').click()

# %%
Quote=[]

# %%
start=0
end=10
for page in range(start,end):
    quote=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in quote:
        Quote.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next_button.click()
    time.sleep(3)

# %%
len(Quote)
# Out:
# 1000

# %%
Author=[]

# %%
start=0
end=10
for page in range(start,end):
    author=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in author:
        Author.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next_button.click()
    time.sleep(3)

# %%
len(Author)
# Out:
# 1000

# %%
Type_Of_Quotes=[]

# %%
start=0
end=10
for page in range(start,end):
    typee=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in typee:
        Type_Of_Quotes.append(i.text)
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next_button.click()
    time.sleep(3)

# %%
len(Type_Of_Quotes)
# Out:
# 1000

# %% [markdown]
# # OUTPUT:

# %%
df = pd.DataFrame({'Quote':Quote,'Author':Author,'Type of Quotes':Type_Of_Quotes})
df
# Out:
#                                                  Quote  \
# 0    The essence of strategy is choosing what not t...
# 1    One cannot and must not try to erase the past ...
# 2    Patriotism means to stand by the country. It d...
# 3    Death is something inevitable. When a man has ...
# 4    You have to love a nation that celebrates its ...
# ..                                                 ...
# 995  Regret for the things we did can be tempered b...
# 996  America... just a nation of two hundred millio...
# 997  For every disciplined effort there is a multip...
# 998  The spiritual journey is individual, highly pe...
# 999  The mind is not a vessel to be filled but a fi...
#
#                      Author                         Type of Quotes
# 0            Amelia Earhart           Inspirational, Life, Success
# 1          Ludwig von Mises                 Peace, War, Government
# 2    Elizabeth Cady Stanton                Life, Strength, Courage
# ...

# %% [markdown]
# # 9. Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks)
#
# from https://www.jagranjosh.com/.

# %%
driver.get('https://www.jagranjosh.com/')

# %%
gk = driver.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a').click()

# %%
pm= driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a').click()

# %%
Name = []

# %%
name = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for i in name :
    Name.append(i.text)

# %%
len(Name )
# Out:
# 18

# %%
Name
# Out:
# ['Jawahar Lal Nehru',
#  'Gulzarilal Nanda (Acting)',
#  'Lal Bahadur Shastri',
#  'Gulzari Lal Nanda  (Acting)',
#  'Indira Gandhi',
#  'Morarji Desai',
#  'Charan Singh',
#  'Indira Gandhi',
#  'Rajiv Gandhi',
#  'V. P. Singh',
#  'Chandra Shekhar',
#  'P. V. Narasimha Rao',
#  'Atal Bihari Vajpayee',
#  'H. D. Deve Gowda',
#  'Inder Kumar Gujral',
#  'Atal Bihari Vajpayee',
#  'Manmohan Singh',
#  'Narendra Modi']

# %%
Born_Dead=[]

# %%
born= driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in born:
    Born_Dead.append(i.text)

# %%
len(Born_Dead)
# Out:
# 18

# %%
Born_Dead
# Out:
# ['(1889–1964)',
#  '(1898-1998)',
#  '(1904–1966)',
#  '(1898-1998)',
#  '(1917–1984)',
#  '(1896–1995)',
#  '(1902–1987)',
#  '(1917–1984)',
#  '(1944–1991)',
#  '(1931–2008)',
#  '(1927–2007)',
#  '(1921–2004)',
#  '(1924- 2018)',
#  '(born 1933)',
#  '(1919–2012)',
#  '(1924-2018)',
#  '(born 1932)',
#  '(born 1950)']

# %%
Term_of_office=[]

# %%
term= driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p')
for i in term[0:18]:
    Term_of_office.append(i.text)

# %%
len(Term_of_office)
# Out:
# 18

# %%
Term_of_office
# Out:
# ['15 August 1947 to 27 May 1964',
#  '16 years, 286 days',
#  '27 May 1964 to 9 June 1964,',
#  '13 days',
#  '9 June 1964 to 11 January 1966',
#  '1 year, 216 days',
#  '11 January 1966 to 24 January 1966',
#  '13 days',
#  '24 January 1966 to 24 March 1977',
#  '11 years, 59 days',
#  '24 March 1977 to  28 July 1979 ',
#  '2 year, 126 days',
#  '28 July 1979 to 14 January 1980',
#  '170 days',
#  '14 January 1980 to 31 October 1984',
#  '4 years, 291 days',
#  '31 October 1984 to 2 December 1989',
#  '5 years, 32 days']

# %%
Remarks =[]

# %%
remark= driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in remark[0:18]:
    Remarks.append(i.text)

# %%
len(Remarks)
# Out:
# 18

# %%
Remarks
# Out:
# ['The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  'First acting PM of India',
#  "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '-',
#  'First female Prime Minister of India',
#  'Oldest to become PM (81 years old) and first to resign from office',
#  'Only PM who did not face the Parliament',
#  'The first lady who served as PM for the second term',
#  'Youngest to become PM (40 years old)',
#  'First PM to step down after a vote of no confidence',
#  'He belongs to  Samajwadi Janata Party',
#  'First PM from south India',
#  'PM for shortest tenure',
#  'He belongs to  Janata Dal',
#  '------',
#  ' The first non-congress PM who completed a full term as PM',
#  ' First Sikh PM',
#  '4th Prime Minister of India who served two consecutive tenures']

# %% [markdown]
# # Output:

# %%
df = pd.DataFrame({'Name':Name,'Born_Dead':Born_Dead,'Term Of Office':Term_of_office,'Remarks':Remarks})
df
# Out:
#                            Name     Born_Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                         Term Of Office  \
# ...

# %% [markdown]
# # 10. Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from
#
# https://www.motor1.com/

# %%
driver.get('https://www.motor1.com/')

# %%
menu = driver.find_element(By.CLASS_NAME,'m1-hamburger-button').click()

# %%
features = driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[5]/button').click()

# %%
List = driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a').click()

# %%
final = driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[1]/div[1]/div/div/div[9]/div/div[1]/h3/a').click()

# %%
Car_name_ =[]

# %%
car_name_=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in car_name_[0:50]:
    Car_name_.append(i.text)

# %%
len(Car_name_)
# Out:
# 50

# %%
Car_name_
# Out:
# ['Drako GTE',
#  'De Tomaso P72',
#  'Ferrari LaFerrari',
#  'Pagani Huayra',
#  'McLaren Elva',
#  'Czinger 21C',
#  'Ferrari Monza',
#  'Gordon Murray T.33',
#  'Koenigsegg Gemera',
#  'Zenvo TSR-S',
#  'Hennessey Venom F5',
#  'Bentley Bacalar',
#  'Hispano Suiza Carmen Boulogne',
#  'Bentley Mulliner Batur',
#  'Deus Vayanne',
#  'SSC Tuatara',
#  'Lotus Evija',
#  'Aston Martin Vulcan',
#  'Delage D12',
#  'McLaren Speedtail',
#  'Rimac Nevera',
#  'Pagani Utopia',
#  'Pininfarina Battista',
#  'Ferrari FXX K Evo',
#  'Gordon Murray T.50',
#  'Lamborghini Countach',
#  'Mercedes-AMG Project One',
#  'Aston Martin Victor',
#  'Hennessey Venom F5 Roadster',
#  'Koenigsegg Jesko',
#  'Aston Martin Valkyrie',
#  'W Motors Lykan Hypersport',
#  'McLaren Solus',
#  'Pagani Huayra Roadster BC',
#  'Bugatti Chiron Pur Sport',
#  'Lamborghini Sian',
#  'Koenigsegg CC850',
#  'Bugatti Chiron Super Sport 300+',
#  'Lamborghini Veneno',
#  'Bugatti Bolide',
#  'Bugatti Mistral',
# ...

# %%
Price_=[]

# %%
price= driver.find_elements(By.XPATH,"//strong")

for j in price[0:50]:
    Price_.append(j.text)

# %%
len(Price_)
# Out:
# 50

# %% [markdown]
# # Output:

# %%
df= pd.DataFrame({'Car Name':Car_name_,'Price':Price_})
df
# Out:
#                            Car Name                 Price
# 0                         Drako GTE   Price: $1.2 Million
# 1                     De Tomaso P72   Price: $1.3 Million
# 2                 Ferrari LaFerrari   Price: $1.4 Million
# 3                     Pagani Huayra   Price: $1.4 Million
# 4                      McLaren Elva
# 5                       Czinger 21C   Price: $1.7 Million
# 6                     Ferrari Monza   Price: $1.7 Million
# 7                Gordon Murray T.33   Price: $1.7 Million
# 8                 Koenigsegg Gemera   Price: $1.7 Million
# 9                       Zenvo TSR-S   Price: $1.7 Million
# 10               Hennessey Venom F5   Price: $1.7 Million
# 11                  Bentley Bacalar   Price: $1.8 Million
# 12    Hispano Suiza Carmen Boulogne   Price: $1.9 Million
# 13           Bentley Mulliner Batur   Price: $1.9 Million
# 14                     Deus Vayanne   Price: $2.0 Million
# 15                      SSC Tuatara   Price: $2.0 Million
# ...
